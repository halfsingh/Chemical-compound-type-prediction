# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense,Dropout
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import tensorflow

# %%
DATA = pd.read_csv('musk_csv.csv')

# %%
DATA.head()
# Out:
#    ID molecule_name conformation_name  f1   f2   f3  f4   f5  f6  f7  ...  \
# 0   1      MUSK-211           211_1+1  46 -108  -60 -69 -117  49  38  ...
# 1   2      MUSK-211          211_1+10  41 -188 -145  22 -117  -6  57  ...
# 2   3      MUSK-211          211_1+11  46 -194 -145  28 -117  73  57  ...
# 3   4      MUSK-211          211_1+12  41 -188 -145  22 -117  -7  57  ...
# 4   5      MUSK-211          211_1+13  41 -188 -145  22 -117  -7  57  ...
#
#    f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  -308    52    -7    39   126   156   -50  -112    96      1
# 1   -59    -2    52   103   136   169   -61  -136    79      1
# 2  -134  -154    57   143   142   165   -67  -145    39      1
# 3   -60    -4    52   104   136   168   -60  -135    80      1
# 4   -60    -4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
DATA.shape
# Out:
# (6598, 170)

# %%
0.2*DATA.shape[0]
# Out:
# 1319.6000000000001

# %%
DATA = DATA.sample(frac=1).reset_index(drop=True)
DATA_TRAIN = DATA.iloc[1320:,:]
DATA_TEST = DATA.iloc[:1320,:]

# %%
DATA_TRAIN.head()
# Out:
#         ID  molecule_name conformation_name   f1   f2   f3   f4   f5   f6  \
# 1320  4168  NON-MUSK-f146        f146_1+235  106 -138 -145  -54 -117   12
# 1321  2384   NON-MUSK-252          252_1+27   44   86   16 -109 -117   35
# 1322  5771  NON-MUSK-j147          j147_1+6   59   26   46  -71 -117   63
# 1323  5554  NON-MUSK-j146         j146_4+83   36  -99 -126   99 -117    1
# 1324  2481   NON-MUSK-252         252_2+114   44   86   15  -63 -117  131
#
#        f7  ...  f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 1320   56  ...   -79  -134  -120   -26    23   389   216   -45  -321      0
# 1321 -163  ...    46   136     9   142   120   162   -66  -148   -12      0
# 1322 -161  ...    15   145   -19   -42    68   196   -40  -131   140      0
# 1323   86  ...   -43  -189   -27     5   106   202   -53  -154   119      0
# 1324 -163  ...   -52   163     9   142   120   163   -66  -149   -13      0
#
# [5 rows x 170 columns]

# %%
DATA_TEST.head()
# Out:
#      ID  molecule_name conformation_name   f1   f2   f3   f4   f5   f6   f7  \
# 0  3067   NON-MUSK-252         252_4+185   35 -196 -128  100  -91    3  -46
# 1  4267  NON-MUSK-f146        f146_1+324  180 -198 -111  -74 -117   14   26
# 2  6385  NON-MUSK-j147        j147_4+199   63 -177   27  -68 -104  190 -108
# 3  3116   NON-MUSK-252         252_4+229   58   30   47  -20 -117 -143 -160
# 4  1318   NON-MUSK-197         197_1+111  287 -194 -145  -70 -117   55   57
#
#    ...  f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  ...  -260  -206   -15    16   109   203   -53  -154   120      0
# 1  ...   -77  -132  -123     5    64   229   -42   -20  -225      0
# 2  ...  -124   124     6    25    86   188   -38  -120   140      0
# 3  ...  -289  -212   -19   -42    73   190   -41  -127   135      0
# 4  ...  -300    58  -128  -120   318   211     2   138   160      0
#
# [5 rows x 170 columns]

# %%
DATA_TRAIN.reset_index(inplace=True,drop=True)

# %%
DATA_TEST.reset_index(inplace=True,drop=True)

# %%
DATA_TEST.shape
# Out:
# (1320, 170)

# %%
DATA_TRAIN.shape
# Out:
# (5278, 170)

# %%
to_drop = ['molecule_name','conformation_name','ID']
DATA_TRAIN.drop(columns=to_drop,inplace=True)
DATA_TEST.drop(columns=to_drop,inplace=True)
# Out:
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
DATA.head()
# Out:
#      ID  molecule_name conformation_name   f1   f2   f3   f4   f5   f6   f7  \
# 0  3067   NON-MUSK-252         252_4+185   35 -196 -128  100  -91    3  -46
# 1  4267  NON-MUSK-f146        f146_1+324  180 -198 -111  -74 -117   14   26
# 2  6385  NON-MUSK-j147        j147_4+199   63 -177   27  -68 -104  190 -108
# 3  3116   NON-MUSK-252         252_4+229   58   30   47  -20 -117 -143 -160
# 4  1318   NON-MUSK-197         197_1+111  287 -194 -145  -70 -117   55   57
#
#    ...  f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  ...  -260  -206   -15    16   109   203   -53  -154   120      0
# 1  ...   -77  -132  -123     5    64   229   -42   -20  -225      0
# 2  ...  -124   124     6    25    86   188   -38  -120   140      0
# 3  ...  -289  -212   -19   -42    73   190   -41  -127   135      0
# 4  ...  -300    58  -128  -120   318   211     2   138   160      0
#
# [5 rows x 170 columns]

# %%
#DATA_TEST.head()

# %%
model = Sequential()

model.add(Dense(units = 166,input_))
model.add(Dense(units = 512))
model.add(Dropout(0.2))
model.add(Dense(units = 128))
model.add(Dense(units = 64))
model.add(Dropout(0.2))
model.add(Dense(units = 32))
model.add(Dense(units = 1))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-7886377b6218> in <module>
#      10 model.add(Dense(units = 1))
#      11 model.build()
# ---> 12 model.summary()
#
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\keras\engine\network.py in summary(self, line_length, positions, print_fn)
#    1305         if not self.built:
#    1306             raise ValueError(
# -> 1307                 'This model has not yet been built. '
#    1308                 'Build the model first by calling build() '
#    1309                 'or calling fit() with some data. '
#
# ValueError: This model has not yet been built. Build the model first by calling build() or calling fit() with some data. Or specify input_shape or batch_input_shape in the first layer for automatic build.

# %%
model.compile(optimizer='adam',loss='mse',metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
X_TRAIN = DATA_TRAIN.iloc[:,:166]
Y_TRAIN = DATA_TRAIN.iloc[:,166:].values
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-64b08d7d0eb3> in <module>
#       1 X_TRAIN = DATA_TRAIN.iloc[:,:166]
#       2 Y_TRAIN = DATA_TRAIN.iloc[:,166:].values
# ----> 3 model.summary()
#
# c:\users\vj\appdata\local\programs\python\python37\lib\site-packages\keras\engine\network.py in summary(self, line_length, positions, print_fn)
#    1305         if not self.built:
#    1306             raise ValueError(
# -> 1307                 'This model has not yet been built. '
#    1308                 'Build the model first by calling build() '
#    1309                 'or calling fit() with some data. '
#
# ValueError: This model has not yet been built. Build the model first by calling build() or calling fit() with some data. Or specify input_shape or batch_input_shape in the first layer for automatic build.

# %%
scaler = StandardScaler()

X_TRAIN = scaler.fit_transform(X_TRAIN)

# %%
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("BEST_MODEL.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)

hist = model.fit(X_TRAIN, Y_TRAIN, validation_split=0.2, epochs =20, batch_size=128, callbacks=[checkpoint])
# Out:
# Train on 4222 samples, validate on 1056 samples
# Epoch 1/20
# 4222/4222 [==============================] - 1s 347us/step - loss: 3.2298 - acc: 0.3325 - val_loss: 0.2254 - val_acc: 0.7027
#
# Epoch 00001: val_loss improved from inf to 0.22538, saving model to BEST_MODEL.h5
# Epoch 2/20
# 4222/4222 [==============================] - 0s 73us/step - loss: 0.3157 - acc: 0.6431 - val_loss: 0.0788 - val_acc: 0.9034
#
# Epoch 00002: val_loss improved from 0.22538 to 0.07882, saving model to BEST_MODEL.h5
# Epoch 3/20
# 4222/4222 [==============================] - 0s 72us/step - loss: 0.2143 - acc: 0.7264 - val_loss: 0.0768 - val_acc: 0.9015
#
# Epoch 00003: val_loss improved from 0.07882 to 0.07684, saving model to BEST_MODEL.h5
# Epoch 4/20
# 4222/4222 [==============================] - 0s 67us/step - loss: 0.1765 - acc: 0.7819 - val_loss: 0.0726 - val_acc: 0.9186
#
# Epoch 00004: val_loss improved from 0.07684 to 0.07259, saving model to BEST_MODEL.h5
# Epoch 5/20
# 4222/4222 [==============================] - 0s 71us/step - loss: 0.1506 - acc: 0.8081 - val_loss: 0.0685 - val_acc: 0.9148
#
# Epoch 00005: val_loss improved from 0.07259 to 0.06854, saving model to BEST_MODEL.h5
# Epoch 6/20
# 4222/4222 [==============================] - 0s 73us/step - loss: 0.1409 - acc: 0.8247 - val_loss: 0.0714 - val_acc: 0.9167
#
# Epoch 00006: val_loss did not improve from 0.06854
# Epoch 7/20
# 4222/4222 [==============================] - 0s 79us/step - loss: 0.1267 - acc: 0.8441 - val_loss: 0.0679 - val_acc: 0.9176
#
# Epoch 00007: val_loss improved from 0.06854 to 0.06795, saving model to BEST_MODEL.h5
# Epoch 8/20
# 4222/4222 [==============================] - 0s 72us/step - loss: 0.1165 - acc: 0.8612 - val_loss: 0.0673 - val_acc: 0.9195
#
# Epoch 00008: val_loss improved from 0.06795 to 0.06730, saving model to BEST_MODEL.h5
# Epoch 9/20
# 4222/4222 [==============================] - 0s 70us/step - loss: 0.1138 - acc: 0.8716 - val_loss: 0.0663 - val_acc: 0.9195
#
# Epoch 00009: val_loss improved from 0.06730 to 0.06632, saving model to BEST_MODEL.h5
# Epoch 10/20
# 4222/4222 [==============================] - 0s 66us/step - loss: 0.1048 - acc: 0.8828 - val_loss: 0.0658 - val_acc: 0.9214
#
# Epoch 00010: val_loss improved from 0.06632 to 0.06577, saving model to BEST_MODEL.h5
# Epoch 11/20
# 4222/4222 [==============================] - 0s 71us/step - loss: 0.1006 - acc: 0.8828 - val_loss: 0.0652 - val_acc: 0.9167
#
# Epoch 00011: val_loss improved from 0.06577 to 0.06517, saving model to BEST_MODEL.h5
# Epoch 12/20
# 4222/4222 [==============================] - 0s 73us/step - loss: 0.0979 - acc: 0.8918 - val_loss: 0.0655 - val_acc: 0.9233
#
# Epoch 00012: val_loss did not improve from 0.06517
# Epoch 13/20
# 4222/4222 [==============================] - 0s 74us/step - loss: 0.0938 - acc: 0.8986 - val_loss: 0.0636 - val_acc: 0.9214
#
# Epoch 00013: val_loss improved from 0.06517 to 0.06362, saving model to BEST_MODEL.h5
# Epoch 14/20
# 4222/4222 [==============================] - 0s 78us/step - loss: 0.0920 - acc: 0.8967 - val_loss: 0.0638 - val_acc: 0.9223
#
# Epoch 00014: val_loss did not improve from 0.06362
# Epoch 15/20
# 4222/4222 [==============================] - 0s 78us/step - loss: 0.0873 - acc: 0.9074 - val_loss: 0.0630 - val_acc: 0.9205
#
# Epoch 00015: val_loss improved from 0.06362 to 0.06296, saving model to BEST_MODEL.h5
# Epoch 16/20
# 4222/4222 [==============================] - 0s 70us/step - loss: 0.0838 - acc: 0.9109 - val_loss: 0.0633 - val_acc: 0.9242
#
# Epoch 00016: val_loss did not improve from 0.06296
# Epoch 17/20
# 4222/4222 [==============================] - 0s 80us/step - loss: 0.0810 - acc: 0.9121 - val_loss: 0.0626 - val_acc: 0.9233
#
# Epoch 00017: val_loss improved from 0.06296 to 0.06263, saving model to BEST_MODEL.h5
# Epoch 18/20
# 4222/4222 [==============================] - 0s 78us/step - loss: 0.0783 - acc: 0.9180 - val_loss: 0.0613 - val_acc: 0.9205
#
# Epoch 00018: val_loss improved from 0.06263 to 0.06134, saving model to BEST_MODEL.h5
# Epoch 19/20
# 4222/4222 [==============================] - 0s 84us/step - loss: 0.0742 - acc: 0.9240 - val_loss: 0.0620 - val_acc: 0.9299
#
# Epoch 00019: val_loss did not improve from 0.06134
# Epoch 20/20
# 4222/4222 [==============================] - 0s 80us/step - loss: 0.0754 - acc: 0.9185 - val_loss: 0.0611 - val_acc: 0.9261
#
# Epoch 00020: val_loss improved from 0.06134 to 0.06114, saving model to BEST_MODEL.h5

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
DATA_TEST_X = DATA_TEST.iloc[:,:166]
DATA_TEST_Y = DATA_TEST.iloc[:,166:]

# %%
PRED_Y = model.predict(DATA_TEST_X)

# %%
for i in range(len(PRED_Y)):
    
    if PRED_Y[i] < 0:
        PRED_Y[i] = 0
    elif PRED_Y[i] > 0:
        PRED_Y[i] = 1

# %%
acc = 0
for i in range(len(PRED_Y)):
    if PRED_Y[i]==DATA_TEST_Y.values[i]:
        acc+=1
        
ACCURACY = (acc/len(PRED_Y))*100
print(ACCURACY)
# Out:
# 93.33333333333333
